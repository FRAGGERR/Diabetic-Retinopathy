# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import keras
import keras.utils
from keras import utils as np_utils

# %%
import tensorflow.keras.layers
import tensorflow as tf

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import concatenate
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Flatten, Dense, Activation, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2
import numpy as np

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'/content/drive/My Drive/DR',
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'/content/drive/My Drive/DR', # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 3))
# Out:
# Found 2248 images belonging to 5 classes.
# Found 562 images belonging to 5 classes.

# %%
import keras
from keras.layers import Dense, Flatten
from keras.optimizers import SGD, Adam

from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
import tensorflow.keras.applications


# Load DenseNet-169 model without top layers
xception_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

xception_model.summary()
# Create a Sequential model
xception = keras.models.Sequential()

# Set layers in densenet169_model to non-trainable
for layer in xception_model.layers:
    layer.trainable = False


# Add layers to the model
xception.add(xception_model)
xception.add(Flatten())
xception.add(Dropout(0.2))
xception.add(Dense(1024,activation='relu'))
xception.add(Dropout(0.2))
xception.add(Dense(512, activation='relu'))
xception.add(Dense(5, activation='softmax'))

xception.summary()

# Compile the model
adam = Adam(learning_rate=0.001)
xception.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy',precision_m, recall_m, f1_m])

# Assuming you have your ImageDataGenerators set up
# train_generator = ...
# validation_generator = ...

# Train the model
graph = xception.fit(train_generator, epochs=25, validation_data=validation_generator)
xception.save("/content/drive/My Drive/xception(ADAM_0.001).h5")


# Print the results
print(graph.history)
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 111, 111, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 111, 111, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 111, 111, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 109, 109, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 109, 109, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 109, 109, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 109, 109, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 109, 109, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 109, 109, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 55, 55, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 55, 55, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (Bat  (None, 55, 55, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_12 (Add)                (None, 55, 55, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 55, 55, 128)          0         ['add_12[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 55, 55, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 55, 55, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 55, 55, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 256)          32768     ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (Bat  (None, 28, 28, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_13 (Add)                (None, 28, 28, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 28, 28, 256)          0         ['add_13[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 28, 28, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 28, 28, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 28, 28, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 728)          186368    ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (Bat  (None, 14, 14, 728)          2912      ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_14 (Add)                (None, 14, 14, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_14[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_15 (Add)                (None, 14, 14, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_14[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_15[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 14, 14, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_15[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_16[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_17 (Add)                (None, 14, 14, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_16[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_17[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_18 (Add)                (None, 14, 14, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_17[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_18[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_19 (Add)                (None, 14, 14, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_18[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_19[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_20 (Add)                (None, 14, 14, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_19[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_20[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_21 (Add)                (None, 14, 14, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_20[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_21[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_22 (Add)                (None, 14, 14, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_21[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_22[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 14, 14, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 14, 14, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 1024)           745472    ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 7, 7, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_7 (Bat  (None, 7, 7, 1024)           4096      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_23 (Add)                (None, 7, 7, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 7, 7, 1536)           1582080   ['add_23[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 7, 7, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 7, 7, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 7, 7, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 7, 7, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 7, 7, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
# ==================================================================================================
# Total params: 20861480 (79.58 MB)
# Trainable params: 20806952 (79.37 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dropout_2 (Dropout)         (None, 100352)            0
#
#  dense_3 (Dense)             (None, 1024)              102761472
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dense_5 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 124150317 (473.60 MB)
# Trainable params: 103288837 (394.02 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________
# Epoch 1/25
# 71/71 [==============================] - 813s 12s/step - loss: 5.6727 - accuracy: 0.5472 - precision_m: 0.5618 - recall_m: 0.5321 - f1_m: 0.5433 - val_loss: 1.1122 - val_accuracy: 0.6815 - val_precision_m: 0.6930 - val_recall_m: 0.6576 - val_f1_m: 0.6747
# Epoch 2/25
# 71/71 [==============================] - 15s 215ms/step - loss: 0.9353 - accuracy: 0.6659 - precision_m: 0.7087 - recall_m: 0.5907 - f1_m: 0.6423 - val_loss: 0.8374 - val_accuracy: 0.6904 - val_precision_m: 0.8017 - val_recall_m: 0.5195 - val_f1_m: 0.6276
# Epoch 3/25
# 71/71 [==============================] - ETA: 0s - loss: 0.7877 - accuracy: 0.7024 - precision_m: 0.7531 - recall_m: 0.6342 - f1_m: 0.6875Epoch 4/25
# 71/71 [==============================] - 15s 215ms/step - loss: 0.7553 - accuracy: 0.7198 - precision_m: 0.7728 - recall_m: 0.6624 - f1_m: 0.7121 - val_loss: 0.9178 - val_accuracy: 0.6690 - val_precision_m: 0.6888 - val_recall_m: 0.6495 - val_f1_m: 0.6681
# Epoch 5/25
# 71/71 [==============================] - 15s 215ms/step - loss: 0.7146 - accuracy: 0.7246 - precision_m: 0.7705 - recall_m: 0.6813 - f1_m: 0.7223 - val_loss: 0.8492 - val_accuracy: 0.6708 - val_precision_m: 0.7280 - val_recall_m: 0.6312 - val_f1_m: 0.6755
# Epoch 6/25
# 71/71 [==============================] - 16s 218ms/step - loss: 0.6515 - accuracy: 0.7522 - precision_m: 0.8014 - recall_m: 0.6954 - f1_m: 0.7435 - val_loss: 0.8016 - val_accuracy: 0.7260 - val_precision_m: 0.7699 - val_recall_m: 0.7020 - val_f1_m: 0.7339
# Epoch 7/25
# 71/71 [==============================] - 17s 240ms/step - loss: 0.6480 - accuracy: 0.7638 - precision_m: 0.8127 - recall_m: 0.7082 - f1_m: 0.7555 - val_loss: 0.9048 - val_accuracy: 0.7135 - val_precision_m: 0.7626 - val_recall_m: 0.6607 - val_f1_m: 0.7075
# Epoch 8/25
# 71/71 [==============================] - 17s 236ms/step - loss: 0.5972 - accuracy: 0.7807 - precision_m: 0.8154 - recall_m: 0.7416 - f1_m: 0.7761 - val_loss: 1.0311 - val_accuracy: 0.6495 - val_precision_m: 0.7031 - val_recall_m: 0.6017 - val_f1_m: 0.6475
# Epoch 9/25
# 71/71 [==============================] - 17s 235ms/step - loss: 0.5888 - accuracy: 0.7718 - precision_m: 0.8046 - recall_m: 0.7298 - f1_m: 0.7645 - val_loss: 0.9195 - val_accuracy: 0.6726 - val_precision_m: 0.7231 - val_recall_m: 0.6316 - val_f1_m: 0.6737
# Epoch 10/25
# 71/71 [==============================] - 15s 214ms/step - loss: 0.5189 - accuracy: 0.8074 - precision_m: 0.8445 - recall_m: 0.7672 - f1_m: 0.8031 - val_loss: 0.9235 - val_accuracy: 0.6815 - val_precision_m: 0.7362 - val_recall_m: 0.6246 - val_f1_m: 0.6747
# Epoch 11/25
# 71/71 [==============================] - 17s 235ms/step - loss: 0.4853 - accuracy: 0.8109 - precision_m: 0.8542 - recall_m: 0.7835 - f1_m: 0.8168 - val_loss: 0.8916 - val_accuracy: 0.6886 - val_precision_m: 0.7384 - val_recall_m: 0.6755 - val_f1_m: 0.7049
# Epoch 12/25
# 71/71 [==============================] - 15s 216ms/step - loss: 0.4278 - accuracy: 0.8412 - precision_m: 0.8641 - recall_m: 0.8072 - f1_m: 0.8341 - val_loss: 0.9785 - val_accuracy: 0.7242 - val_precision_m: 0.7390 - val_recall_m: 0.6950 - val_f1_m: 0.7161
# Epoch 13/25
# 71/71 [==============================] - 16s 220ms/step - loss: 0.4277 - accuracy: 0.8341 - precision_m: 0.8595 - recall_m: 0.8147 - f1_m: 0.8361 - val_loss: 1.0803 - val_accuracy: 0.6530 - val_precision_m: 0.6887 - val_recall_m: 0.6082 - val_f1_m: 0.6451
# Epoch 14/25
# 71/71 [==============================] - 15s 216ms/step - loss: 0.4949 - accuracy: 0.8167 - precision_m: 0.8451 - recall_m: 0.7962 - f1_m: 0.8195 - val_loss: 0.9398 - val_accuracy: 0.6904 - val_precision_m: 0.7526 - val_recall_m: 0.6329 - val_f1_m: 0.6866
# Epoch 15/25
# 71/71 [==============================] - 15s 215ms/step - loss: 0.4574 - accuracy: 0.8314 - precision_m: 0.8537 - recall_m: 0.8015 - f1_m: 0.8263 - val_loss: 1.0246 - val_accuracy: 0.7011 - val_precision_m: 0.7255 - val_recall_m: 0.6690 - val_f1_m: 0.6954
# Epoch 16/25
# 71/71 [==============================] - 16s 222ms/step - loss: 0.4787 - accuracy: 0.8203 - precision_m: 0.8465 - recall_m: 0.8015 - f1_m: 0.8228 - val_loss: 1.0580 - val_accuracy: 0.7100 - val_precision_m: 0.7484 - val_recall_m: 0.6908 - val_f1_m: 0.7181
# Epoch 17/25
# 71/71 [==============================] - 16s 221ms/step - loss: 0.3672 - accuracy: 0.8683 - precision_m: 0.8861 - recall_m: 0.8530 - f1_m: 0.8689 - val_loss: 1.0141 - val_accuracy: 0.6922 - val_precision_m: 0.7172 - val_recall_m: 0.6723 - val_f1_m: 0.6936
# Epoch 18/25
# 71/71 [==============================] - 16s 231ms/step - loss: 0.4000 - accuracy: 0.8448 - precision_m: 0.8637 - recall_m: 0.8204 - f1_m: 0.8411 - val_loss: 0.9013 - val_accuracy: 0.7456 - val_precision_m: 0.7571 - val_recall_m: 0.7166 - val_f1_m: 0.7362
# Epoch 19/25
# 71/71 [==============================] - 16s 230ms/step - loss: 0.3969 - accuracy: 0.8501 - precision_m: 0.8751 - recall_m: 0.8301 - f1_m: 0.8517 - val_loss: 1.1770 - val_accuracy: 0.6993 - val_precision_m: 0.7203 - val_recall_m: 0.6908 - val_f1_m: 0.7050
# Epoch 20/25
# 71/71 [==============================] - 17s 239ms/step - loss: 0.3958 - accuracy: 0.8510 - precision_m: 0.8741 - recall_m: 0.8239 - f1_m: 0.8475 - val_loss: 1.0742 - val_accuracy: 0.6904 - val_precision_m: 0.7259 - val_recall_m: 0.6659 - val_f1_m: 0.6942
# Epoch 21/25
# 71/71 [==============================] - 16s 229ms/step - loss: 0.2919 - accuracy: 0.8870 - precision_m: 0.9053 - recall_m: 0.8724 - f1_m: 0.8882 - val_loss: 1.0808 - val_accuracy: 0.7242 - val_precision_m: 0.7404 - val_recall_m: 0.7012 - val_f1_m: 0.7194
# Epoch 22/25
# 71/71 [==============================] - 17s 235ms/step - loss: 0.3062 - accuracy: 0.8790 - precision_m: 0.8973 - recall_m: 0.8609 - f1_m: 0.8784 - val_loss: 1.0251 - val_accuracy: 0.7331 - val_precision_m: 0.7514 - val_recall_m: 0.7228 - val_f1_m: 0.7365
# Epoch 23/25
# 71/71 [==============================] - 16s 219ms/step - loss: 0.3735 - accuracy: 0.8612 - precision_m: 0.8825 - recall_m: 0.8380 - f1_m: 0.8590 - val_loss: 1.0537 - val_accuracy: 0.7206 - val_precision_m: 0.7361 - val_recall_m: 0.7085 - val_f1_m: 0.7218
# Epoch 24/25
# 71/71 [==============================] - 16s 219ms/step - loss: 0.3010 - accuracy: 0.8906 - precision_m: 0.9107 - recall_m: 0.8754 - f1_m: 0.8924 - val_loss: 1.0200 - val_accuracy: 0.7349 - val_precision_m: 0.7675 - val_recall_m: 0.7160 - val_f1_m: 0.7404
# Epoch 25/25
# 71/71 [==============================] - 15s 217ms/step - loss: 0.2817 - accuracy: 0.8915 - precision_m: 0.9078 - recall_m: 0.8790 - f1_m: 0.8929 - val_loss: 1.1748 - val_accuracy: 0.7349 - val_precision_m: 0.7431 - val_recall_m: 0.7203 - val_f1_m: 0.7314
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# {'loss': [5.672734260559082, 0.9353090524673462, 0.7876554131507874, 0.7552802562713623, 0.7146140336990356, 0.6515432596206665, 0.648003101348877, 0.5972341895103455, 0.5887534618377686, 0.5188699960708618, 0.4853261411190033, 0.4278230369091034, 0.4276829659938812, 0.4948556125164032, 0.4574497938156128, 0.47866472601890564, 0.3671535551548004, 0.39995846152305603, 0.3968861401081085, 0.3957723379135132, 0.29186010360717773, 0.30618777871131897, 0.3734913766384125, 0.3009510934352875, 0.2817016541957855], 'accuracy': [0.5471529960632324, 0.6659252643585205, 0.7024021148681641, 0.7197508811950684, 0.724644124507904, 0.7522242069244385, 0.7637900114059448, 0.7806939482688904, 0.7717971801757812, 0.8073843121528625, 0.810943067073822, 0.8411921858787537, 0.8340747356414795, 0.8167259693145752, 0.8314056992530823, 0.8202847242355347, 0.8683273792266846, 0.8447508811950684, 0.8500889539718628, 0.850978672504425, 0.8870106935501099, 0.8790035843849182, 0.8612099885940552, 0.8905693888664246, 0.891459047794342], 'precision_m': [0.5617625117301941, 0.7086763381958008, 0.7531154751777649, 0.7727785110473633, 0.7705245018005371, 0.8014039397239685, 0.8126885890960693, 0.8153939843177795, 0.8046048283576965, 0.8445356488227844, 0.854223906993866, 0.8640745282173157, 0.8595033288002014, 0.8450638055801392, 0.8537033796310425, 0.8465163111686707, 0.88606196641922, 0.8637083768844604, 0.8750556707382202, 0.8741140961647034, 0.9052675366401672, 0.8972743153572083, 0.8824788928031921, 0.9107113480567932, 0.90777188539505], 'recall_m': [0.5321303009986877, 0.5906690359115601, 0.6342429518699646, 0.6624119877815247, 0.6813380122184753, 0.6954225301742554, 0.7081866264343262, 0.7416373491287231, 0.7297534942626953, 0.76716548204422, 0.783450722694397, 0.8072183132171631, 0.814700722694397, 0.796214759349823, 0.8014965057373047, 0.8014965057373047, 0.8529929518699646, 0.8204225301742554, 0.8301056623458862, 0.8239436745643616, 0.8723591566085815, 0.86091548204422, 0.8380281925201416, 0.8754401206970215, 0.8789612650871277], 'f1_m': [0.5433493256568909, 0.642302393913269, 0.6875078082084656, 0.7120899558067322, 0.7223119139671326, 0.7435035705566406, 0.755463719367981, 0.7761442065238953, 0.7645054459571838, 0.8031095862388611, 0.816824734210968, 0.8341103196144104, 0.8360714316368103, 0.8194593191146851, 0.8262854814529419, 0.8227875232696533, 0.8689464926719666, 0.8411047458648682, 0.8517182469367981, 0.8474941849708557, 0.8882430791854858, 0.8784177899360657, 0.8590492606163025, 0.8923516869544983, 0.8928541541099548], 'val_loss': [1.1121808290481567, 0.8374322056770325, 0.8525223731994629, 0.9178407192230225, 0.8491575121879578, 0.8016330599784851, 0.9047724008560181, 1.0311038494110107, 0.9195258021354675, 0.9235216379165649, 0.8915697336196899, 0.978462815284729, 1.080313801765442, 0.939755916595459, 1.0246307849884033, 1.0579943656921387, 1.0140563249588013, 0.9012916684150696, 1.1769721508026123, 1.0741738080978394, 1.0808475017547607, 1.0250658988952637, 1.0537223815917969, 1.0200275182724, 1.1747674942016602], 'val_accuracy': [0.6814946532249451, 0.690391480922699, 0.6992882490158081, 0.6690391302108765, 0.6708185076713562, 0.725978672504425, 0.7135231494903564, 0.6494662165641785, 0.6725978851318359, 0.6814946532249451, 0.6886121034622192, 0.7241992950439453, 0.6530249118804932, 0.690391480922699, 0.7010676264762878, 0.709964394569397, 0.6921707987785339, 0.745551586151123, 0.6992882490158081, 0.690391480922699, 0.7241992950439453, 0.7330960631370544, 0.7206405401229858, 0.7348754405975342, 0.7348754405975342], 'val_precision_m': [0.6930469870567322, 0.8017324805259705, 0.7504919767379761, 0.6887795329093933, 0.7280251979827881, 0.7699171900749207, 0.7626139521598816, 0.7030728459358215, 0.7230982184410095, 0.7361823320388794, 0.7383800745010376, 0.738987147808075, 0.6886761784553528, 0.7525995969772339, 0.7255251407623291, 0.7483893632888794, 0.7172439098358154, 0.7571451663970947, 0.7203414440155029, 0.7259264588356018, 0.7403914928 ...

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('DenseNet201 Accuracy for DR Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['loss'])
plt.plot(graph.history['val_loss'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('DenseNet201 Loss for DR Dataset')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()
